# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.2

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('data.csv')
df.plot(x='Duration', y='Calories', kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
